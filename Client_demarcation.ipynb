# %%
import pandas as ed
Data = ed.read_csv("/content/CS Review (1).csv")

# %%
import numpy as np

# %%
Data
# Out:
#                           Brand Name  Company Size       ARR  Region Features  \
# 0                                NaN           NaN       NaN     NaN      Web
# 1                               R&R            NaN  180000.0     NaN       No
# 2              Edupristine Education         169.0   69996.0     NaN      Yes
# 3                           Lybrate          205.0  150000.0   Delhi      Yes
# 4               POC: Landmark Group            NaN  240000.0  Gujrat       No
# ..                               ...           ...       ...     ...      ...
# 139               Country Chicken Co          37.0       NaN     NaN      Yes
# 140                         MMTV Ltd         211.0       NaN     NaN      Yes
# 141        ICRI Life Science Pvt Ltd           NaN       NaN     NaN      Yes
# 142               AshFash Lifestyle            NaN  144000.0     NaN      Yes
# 143  JP Infra Realty Private Limited         467.0       NaN     NaN      Yes
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Feature Count
# 0     WhatsApp   Facebook  Instagram    Twitter   Telegram            NaN
# 1          Yes         No         No         No         No            1.0
# 2           No         No         No         No         No            1.0
# 3          Yes         No         No         No         No            2.0
# 4          Yes         No         No         No         No            1.0
# ..         ...        ...        ...        ...        ...            ...
# 139        Yes        Yes        Yes        Yes         No            5.0
# 140        Yes        Yes        Yes        Yes         No            5.0
# 141        Yes        Yes        Yes        Yes         No            5.0
# 142        Yes        Yes        Yes        Yes         No            5.0
# 143        Yes        Yes        Yes        Yes         No            5.0
#
# [144 rows x 11 columns]

# %%
Data = Data.fillna(0)

# %%
# First quartile (Q1)
ARR_Q1 = np.percentile(Data['ARR'], 25,interpolation = 'midpoint')
# Out:
# <ipython-input-7-293b097ed876>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   ARR_Q1 = np.percentile(Data['ARR'], 25,interpolation = 'midpoint')

# %%
ARR_Q2 = np.percentile(Data['ARR'], 50, interpolation= 'midpoint')
# Out:
# <ipython-input-8-767d752cfd1f>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   ARR_Q2 = np.percentile(Data['ARR'], 50, interpolation= 'midpoint')

# %%
ARR_Q3 = np.percentile(Data['ARR'], 75, interpolation= 'midpoint')
# Out:
# <ipython-input-9-cdf21a5a32f6>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   ARR_Q3 = np.percentile(Data['ARR'], 75, interpolation= 'midpoint')

# %%
CompanySize_Q1 = np.percentile(Data['Company Size'], 25,interpolation = 'midpoint')
# Out:
# <ipython-input-10-97f445be13fa>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   CompanySize_Q1 = np.percentile(Data['Company Size'], 25,interpolation = 'midpoint')

# %%
CompanySize_Q2 = np.percentile(Data['Company Size'], 50,interpolation = 'midpoint')
# Out:
# <ipython-input-11-f5a234e324f7>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   CompanySize_Q2 = np.percentile(Data['Company Size'], 50,interpolation = 'midpoint')

# %%
CompanySize_Q3 = np.percentile(Data['Company Size'], 75,interpolation = 'midpoint')
# Out:
# <ipython-input-12-851eb24590cf>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   CompanySize_Q3 = np.percentile(Data['Company Size'], 75,interpolation = 'midpoint')

# %%
Data
# Out:
#                           Brand Name  Company Size       ARR  Region Features  \
# 0                                  0           0.0       0.0       0      Web
# 1                               R&R            0.0  180000.0       0       No
# 2              Edupristine Education         169.0   69996.0       0      Yes
# 3                           Lybrate          205.0  150000.0   Delhi      Yes
# 4               POC: Landmark Group            0.0  240000.0  Gujrat       No
# ..                               ...           ...       ...     ...      ...
# 139               Country Chicken Co          37.0       0.0       0      Yes
# 140                         MMTV Ltd         211.0       0.0       0      Yes
# 141        ICRI Life Science Pvt Ltd           0.0       0.0       0      Yes
# 142               AshFash Lifestyle            0.0  144000.0       0      Yes
# 143  JP Infra Realty Private Limited         467.0       0.0       0      Yes
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Feature Count
# 0     WhatsApp   Facebook  Instagram    Twitter   Telegram            0.0
# 1          Yes         No         No         No         No            1.0
# 2           No         No         No         No         No            1.0
# 3          Yes         No         No         No         No            2.0
# 4          Yes         No         No         No         No            1.0
# ..         ...        ...        ...        ...        ...            ...
# 139        Yes        Yes        Yes        Yes         No            5.0
# 140        Yes        Yes        Yes        Yes         No            5.0
# 141        Yes        Yes        Yes        Yes         No            5.0
# 142        Yes        Yes        Yes        Yes         No            5.0
# 143        Yes        Yes        Yes        Yes         No            5.0
#
# [144 rows x 11 columns]

# %%
ARR_List = []
Feature_List = []
CompanySize_List = []

# %%
for i in range(len(Data)) :  
  if Data.loc[i]['Company Size'] < CompanySize_Q1 or  Data.loc[i]['Company Size'] == CompanySize_Q1 :
    CompanySize_List.append('.50')
  elif Data.loc[i]['Company Size'] > CompanySize_Q1 or  Data.loc[i]['Company Size'] == CompanySize_Q1 and  Data.loc[i]['Company Size'] < CompanySize_Q2 :
    CompanySize_List.append('1.00')
  elif Data.loc[i]['Company Size'] > CompanySize_Q2 or  Data.loc[i]['Company Size'] == CompanySize_Q2 and  Data.loc[i]['Company Size'] < CompanySize_Q3 :
    CompanySize_List.append('1.50')
  elif Data.loc[i]['Company Size'] > CompanySize_Q3 :
    CompanySize_List.append('2.00')
  if Data.loc[i]['ARR'] < ARR_Q1 or  Data.loc[i]['ARR'] == ARR_Q1:
    ARR_List.append('1')
  elif Data.loc[i]['ARR'] > ARR_Q1 or  Data.loc[i]['ARR'] == ARR_Q1 and Data.loc[i]['ARR'] < ARR_Q2 :
    ARR_List.append('2')
  elif Data.loc[i]['ARR'] > ARR_Q2 or  Data.loc[i]['ARR'] == ARR_Q2 and Data.loc[i]['ARR'] < ARR_Q3 :
    ARR_List.append('3')
  elif Data.loc[i]['ARR'] > ARR_Q3 :
    ARR_List.append('4')
  if Data.loc[i]['Feature Count'] == 0 or Data.loc[i]['Feature Count']  == 1 :
    Feature_List.append('.75')
  if Data.loc[i]['Feature Count'] == 2 :
    Feature_List.append('1.5')
  if Data.loc[i]['Feature Count']  == 3 :
    Feature_List.append('2.25')
  if Data.loc[i]['Feature Count'] > 3 :
    Feature_List.append('3.00')

# %%
Region_List = []
for i in range(len(Data)) :
  if Data.loc[i]['Region'] == 'India' :
    Region_List.append(1)
  elif Data.loc[i]['Region'] == 'Outside India' :
    Region_List.append(2)

# %%
len(ARR_List)
# Out:
# 144

# %%
len(Feature_List)
# Out:
# 144

# %%
len(CompanySize_List)
# Out:
# 144

# %%
len(Data)
# Out:
# 144

# %%
Data['ARR_class'] = ARR_List
Data['Feature_class'] = Feature_List 
Data['CompanySize_class'] = CompanySize_List
Data['Region_Class'] = Region_List
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-e54aa87abe67> in <cell line: 4>()
#       2 Data['Feature_class'] = Feature_List
#       3 Data['CompanySize_class'] = CompanySize_List
# ----> 4 Data['Region_Class'] = Region_List
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
#    4916         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (144)

# %%
Data
# Out:
#                           Brand Name  Company Size       ARR  Region Features  \
# 0                                  0           0.0       0.0       0      Web
# 1                               R&R            0.0  180000.0       0       No
# 2              Edupristine Education         169.0   69996.0       0      Yes
# 3                           Lybrate          205.0  150000.0   Delhi      Yes
# 4               POC: Landmark Group            0.0  240000.0  Gujrat       No
# ..                               ...           ...       ...     ...      ...
# 139               Country Chicken Co          37.0       0.0       0      Yes
# 140                         MMTV Ltd         211.0       0.0       0      Yes
# 141        ICRI Life Science Pvt Ltd           0.0       0.0       0      Yes
# 142               AshFash Lifestyle            0.0  144000.0       0      Yes
# 143  JP Infra Realty Private Limited         467.0       0.0       0      Yes
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Feature Count  \
# 0     WhatsApp   Facebook  Instagram    Twitter   Telegram            0.0
# 1          Yes         No         No         No         No            1.0
# 2           No         No         No         No         No            1.0
# 3          Yes         No         No         No         No            2.0
# 4          Yes         No         No         No         No            1.0
# ..         ...        ...        ...        ...        ...            ...
# 139        Yes        Yes        Yes        Yes         No            5.0
# 140        Yes        Yes        Yes        Yes         No            5.0
# 141        Yes        Yes        Yes        Yes         No            5.0
# 142        Yes        Yes        Yes        Yes         No            5.0
# 143        Yes        Yes        Yes        Yes         No            5.0
#
#     ARR_class Feature_class CompanySize_class
# 0           1           .75               .50
# 1           2           .75               .50
# 2           2           .75              1.00
# 3           2           1.5              1.00
# 4           2           .75               .50
# ..        ...           ...               ...
# 139         1          3.00              1.00
# 140         1          3.00              1.00
# 141         1          3.00               .50
# 142         2          3.00               .50
# 143         1          3.00              1.00
#
# [144 rows x 14 columns]

# %%
Data.loc[2]
# Out:
# Brand Name           Edupristine Education
# Company Size                         169.0
# ARR                                69996.0
# Region                                   0
# Features                               Yes
# Unnamed: 5                              No
# Unnamed: 6                              No
# Unnamed: 7                              No
# Unnamed: 8                              No
# Unnamed: 9                              No
# Feature Count                          1.0
# ARR_class                                2
# Feature_class                          .75
# CompanySize_class                     1.00
# Name: 2, dtype: object

# %%
x = []
for i in Data['Company Size']:
  if i < CompanySize_Q1 or i == CompanySize_Q1 :
    x.append('Bronze')
  elif i > CompanySize_Q1 or i == CompanySize_Q1 and i < CompanySize_Q2 :
    x.append('Silver')
  elif i> CompanySize_Q2 or i == CompanySize_Q2 and  i < CompanySize_Q3 :
    x.append('Gold')
  elif i > CompanySize_Q3 :
    x.append('Platinum')

# %%
len(x)
# Out:
# 144

# %%
ARR_Q3
# Out:
# 180000.0

# %%
aggregated_values = []
for i in range(len(Data)):
    arr = int(ARR_List [i])
    comp = float(CompanySize_List[i])
    feature = float(Feature_List [i])
    Region = int(Region_List[i])
    s = float(arr+comp+feature+Region)
    if s < 3 or s == 3:
      aggregated_values.append('Bronze')
    elif s > 3 or s <= 5 :
      aggregated_values.append('Silver')
    elif s > 5 or s <= 6 :
      aggregated_values.append('Gold')  
    elif s > 6 :
      aggregated_values.append('Platinum')

# %%
Data['Category'] = aggregated_values

# %%
Data
# Out:
#                           Brand Name  Company Size       ARR  Region Features  \
# 0                                  0           0.0       0.0       0      Web
# 1                               R&R            0.0  180000.0       0       No
# 2              Edupristine Education         169.0   69996.0       0      Yes
# 3                           Lybrate          205.0  150000.0   Delhi      Yes
# 4               POC: Landmark Group            0.0  240000.0  Gujrat       No
# ..                               ...           ...       ...     ...      ...
# 139               Country Chicken Co          37.0       0.0       0      Yes
# 140                         MMTV Ltd         211.0       0.0       0      Yes
# 141        ICRI Life Science Pvt Ltd           0.0       0.0       0      Yes
# 142               AshFash Lifestyle            0.0  144000.0       0      Yes
# 143  JP Infra Realty Private Limited         467.0       0.0       0      Yes
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Feature Count  \
# 0     WhatsApp   Facebook  Instagram    Twitter   Telegram            0.0
# 1          Yes         No         No         No         No            1.0
# 2           No         No         No         No         No            1.0
# 3          Yes         No         No         No         No            2.0
# 4          Yes         No         No         No         No            1.0
# ..         ...        ...        ...        ...        ...            ...
# 139        Yes        Yes        Yes        Yes         No            5.0
# 140        Yes        Yes        Yes        Yes         No            5.0
# 141        Yes        Yes        Yes        Yes         No            5.0
# 142        Yes        Yes        Yes        Yes         No            5.0
# 143        Yes        Yes        Yes        Yes         No            5.0
#
#     ARR_class Feature_class CompanySize_class Category
# 0           1           .75               .50   Bronze
# 1           2           .75               .50   Silver
# 2           2           .75              1.00   Silver
# 3           2           1.5              1.00   Silver
# 4           2           .75               .50   Silver
# ..        ...           ...               ...      ...
# 139         1          3.00              1.00   Silver
# 140         1          3.00              1.00   Silver
# 141         1          3.00               .50   Silver
# 142         2          3.00               .50   Silver
# 143         1          3.00              1.00   Silver
#
# [144 rows x 15 columns]

# %%
import matplotlib.pyplot as plt

# %%
labels = ['Silver', 'Bronze', 'Gold', 'Platinum']

# %%
count_silver = aggregated_values.count('Silver')
count_gold = aggregated_values.count('Gold')
count_bronze = aggregated_values.count('Bronze')
count_platinum =  aggregated_values.count('Platinum')

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
labels = ['Silver', 'Bronze', 'Gold', 'Platinum']
sizes = [count_silver, count_bronze, count_gold, count_platinum]  # Example sizes, you can replace them with your own data

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Add a title
plt.title('Distribution of Categories')

# Display the pie chart
plt.show()

# %%
count_platinum
# Out:
# 0
